# %%
# !git clone https://github.com/theiniyanvlogs-lab/WatchExpert_AI_Chatbot.git
# %cd WatchExpert_AI_Chatbot
# Out:
# Cloning into 'WatchExpert_AI_Chatbot'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 137 (delta 70), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (137/137), 190.71 KiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/WatchExpert_AI_Chatbot

# %%
# !pip install -q gradio faiss-cpu sentence-transformers pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 91.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 33.9 MB/s eta 0:00:00

# %%
# !pwd
# !ls -R
# Out:
# /content/WatchExpert_AI_Chatbot
# .:
# app.py	chatbot.py  create_vector_db.py  knowledge  README.md  requirements.txt
#
# ./knowledge:
# Casio.pdf    Offers_and_Discounts.pdf  Tissot.pdf
# Citizen.pdf  Rolex.pdf		       Titan.pdf
# FAQs.pdf     Seiko.pdf		       Warranty_and_Returns.pdf
# Fossil.pdf   Shop_Details.pdf	       Watch_Catalog.pdf

# %%
# !python create_vector_db.py
# Out:
# ...
# Loading Sentence Transformer Model...
# ...
# modules.json: 100% 349/349 [00:00<00:00, 1.87MB/s]
# ...
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 625kB/s]
# README.md: 100% 10.5k/10.5k [00:00<00:00, 34.1MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 345kB/s]
# config.json: 100% 612/612 [00:00<00:00, 3.62MB/s]
#
# model.safetensors: downloading bytes:  94% 85.0M/90.9M [00:00<00:00, 125MB/s, 7.22MB/s  ]
# model.safetensors: downloading bytes: 100% 85.0M/85.0M [00:01<00:00, 81.1MB/s, 8.24MB/s  ]
# model.safetensors: reconstructing file: 100% 90.9M/90.9M [00:01<00:00, 86.7MB/s, 8.90MB/s  ]
# Loading weights: 100% 103/103 [00:00<00:00, 24353.87it/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.78MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 9.65MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 32.2MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 511kB/s]
# config.json: 100% 190/190 [00:00<00:00, 951kB/s]
#
# Loading PDFs...
#
# ...

# %%
# !python create_vector_db.py
# Out:
# ...
# Loading Sentence Transformer Model...
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 5377.71it/s]
#
# Loading PDFs...
#
# Reading: Casio.pdf
# Reading: Citizen.pdf
# Reading: FAQs.pdf
# Reading: Fossil.pdf
# Reading: Offers_and_Discounts.pdf
# Reading: Rolex.pdf
# Reading: Seiko.pdf
# Reading: Shop_Details.pdf
# Reading: Tissot.pdf
# Reading: Titan.pdf
# Reading: Warranty_and_Returns.pdf
# Reading: Watch_Catalog.pdf
#
# ...
# Knowledge Base Summary
# ...
# PDF Files : 12
# Chunks    : 12
#
# Generating Embeddings...
#
# Batches: 100% 1/1 [00:00<00:00,  4.86it/s]
#
# ...
# WatchExpert AI Chatbot
# Vector Database Created Successfully
# ...
# PDF Files Processed : 12
# Text Chunks         : 12
# Embedding Model     : all-MiniLM-L6-v2
# FAISS Index         : vector_db/watch_index.faiss
# Chunks File         : vector_db/chunks.pkl
#
# Ready to launch app.py

# %%
# !ls -lh vector_db
# Out:
# total 24K
# -rw-r--r-- 1 root root 1.5K Jul 20 05:34 chunks.pkl
# -rw-r--r-- 1 root root  19K Jul 20 05:34 watch_index.faiss

# %%
# !python app.py
# Out:
# ...
# Loading Sentence Transformer...
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 16899.28it/s]
# Loading FAISS Index...
# Vector Database Loaded Successfully!
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://71e635948e2843045d.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
